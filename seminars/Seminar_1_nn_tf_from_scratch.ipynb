# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook

from sklearn.metrics import average_precision_score

# %%
df = pd.read_csv('bank_data.csv')
df.head()
# Out:
#    age        job   marital            education  default housing loan  \
# 0   39     admin.   married    university.degree  unknown      no   no
# 1   31   services  divorced          high.school       no     yes   no
# 2   34   services  divorced          high.school       no     yes   no
# 3   23     admin.    single  professional.course       no     yes   no
# 4   63  housemaid   married             basic.4y       no      no   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   jul         thu  ...         3    999         0  nonexistent
# 1  cellular   jul         mon  ...         1    999         0  nonexistent
# 2  cellular   may         fri  ...         1    999         0  nonexistent
# 3  cellular   jul         wed  ...         2    999         0  nonexistent
# 4  cellular   aug         tue  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          1.4          93.918          -42.7      4.968       5228.1 -1
# 1          1.4          93.918          -42.7      4.960       5228.1 -1
# 2         -1.8          92.893          -46.2      1.250       5099.1 -1
# 3          1.4          93.918          -42.7      4.963       5228.1 -1
# 4         -2.9          92.201          -31.4      0.838       5076.2  1
#
# [5 rows x 21 columns]

# %%
data = df.select_dtypes(['int64', 'float64'])
X = data.drop(columns=['y', 'pdays']).values
data.drop(columns=['pdays', 'y'])
# Out:
#       age  duration  campaign  previous  emp.var.rate  cons.price.idx  \
# 0      39        67         3         0           1.4          93.918
# 1      31       522         1         0           1.4          93.918
# 2      34        84         1         0          -1.8          92.893
# 3      23       332         2         0           1.4          93.918
# 4      63       479         1         0          -2.9          92.201
# ...   ...       ...       ...       ...           ...             ...
# 9275   55       146         1         0           1.4          94.465
# 9276   31       115         1         0          -0.1          93.200
# 9277   36       874         1         0           1.4          93.918
# 9278   31       870         1         0           1.4          93.918
# 9279   35         4         1         0          -0.1          93.798
#
#       cons.conf.idx  euribor3m  nr.employed
# 0             -42.7      4.968       5228.1
# 1             -42.7      4.960       5228.1
# 2             -46.2      1.250       5099.1
# 3             -42.7      4.963       5228.1
# 4             -31.4      0.838       5076.2
# ...             ...        ...          ...
# 9275          -41.8      4.958       5228.1
# 9276          -42.0      4.474       5195.8
# 9277          -42.7      4.961       5228.1
# 9278          -42.7      4.963       5228.1
# 9279          -40.4      4.968       5195.8
#
# [9280 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
ss.fit(X[:8000])
X = ss.transform(data.drop(columns=['y', 'pdays']).values)

# %%
y = (data.y == 1).astype(int).values
X_train, X_val, y_train, y_val = X[:8000], X[8000:], y[:8000], y[8000:]

# %%
tf.__version__
# Out:
# '1.15.0'

# %%
X_train.shape
# Out:
# (8000, 9)

# %% [markdown]
# $W_{9x3}; b_{1x3}; U_{3x1}; c_{1x1}$

# %%
tf.reset_default_graph()
np.random.seed(2020)

num_hidden = 100

X_plh = tf.placeholder(np.float64, shape=[None, 9], name='X')
y_plh = tf.placeholder(np.float64, shape=[None, 1], name='y')

W = tf.get_variable('W', initializer=np.random.normal(0, 1/3, size=[9, num_hidden]))
b = tf.get_variable('b', initializer=np.zeros(shape=[num_hidden]) + np.random.normal(0, 1/3, size=[num_hidden]) / 10)
U = tf.get_variable('U', initializer=np.random.normal(0, np.sqrt(1/num_hidden), size=[num_hidden, 1]))
c = tf.get_variable('c', initializer=np.array([0]).astype('float64'))

out = (tf.nn.relu(X_plh @ W + b) @ U + c)
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=y_plh, logits=out)

optimizer = tf.train.AdamOptimizer().minimize(loss)
# Out:
# WARNING:tensorflow:From /opt/anaconda3/envs/soccer_env/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
num_epochs = 100
batch_size = 1024
num_obs = 8000

# %%
y_train, y_val = y_train[:, None], y_val[:, None]

# %%
auc_vals, acc_vals = [], []

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

for epoch in tqdm_notebook(range(num_epochs)):
    for idx_batch in range(num_obs // batch_size + 1):
        X_batch = X_train[idx_batch * batch_size : (idx_batch+1) * batch_size]
        y_batch = y_train[idx_batch * batch_size : (idx_batch+1) * batch_size]
        
        sess.run(optimizer, feed_dict={X_plh: X_batch, y_plh: y_batch})
        
    train_out = sess.run(out, feed_dict={X_plh: X_train, y_plh: y_train})
    val_out = sess.run(out, feed_dict={X_plh: X_val, y_plh: y_val})
    
    acc_train = np.mean((train_out > 0).astype(int) == (y_train > 0).astype(int))
    acc_val = np.mean((val_out > 0).astype(int) == (y_val > 0).astype(int))
    acc_vals.append(acc_val)
    
    print(f'Epoch {epoch}; Accuracy train: {acc_train:.4f}; Accuracy val: {acc_val:.4f}')
# Out:
# /opt/anaconda3/envs/soccer_env/lib/python3.7/site-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Epoch 0; Accuracy train: 0.4358; Accuracy val: 0.4445
# Epoch 1; Accuracy train: 0.5949; Accuracy val: 0.5734
# Epoch 2; Accuracy train: 0.6760; Accuracy val: 0.6547
# Epoch 3; Accuracy train: 0.8016; Accuracy val: 0.7828
# Epoch 4; Accuracy train: 0.8080; Accuracy val: 0.7836
# Epoch 5; Accuracy train: 0.8085; Accuracy val: 0.7836
# Epoch 6; Accuracy train: 0.8176; Accuracy val: 0.7852
# Epoch 7; Accuracy train: 0.8240; Accuracy val: 0.7914
# Epoch 8; Accuracy train: 0.8281; Accuracy val: 0.7969
# Epoch 9; Accuracy train: 0.8327; Accuracy val: 0.8023
# Epoch 10; Accuracy train: 0.8383; Accuracy val: 0.8102
# Epoch 11; Accuracy train: 0.8425; Accuracy val: 0.8148
# Epoch 12; Accuracy train: 0.8455; Accuracy val: 0.8187
# Epoch 13; Accuracy train: 0.8511; Accuracy val: 0.8250
# Epoch 14; Accuracy train: 0.8534; Accuracy val: 0.8281
# Epoch 15; Accuracy train: 0.8552; Accuracy val: 0.8313
# Epoch 16; Accuracy train: 0.8552; Accuracy val: 0.8305
# Epoch 17; Accuracy train: 0.8570; Accuracy val: 0.8328
# Epoch 18; Accuracy train: 0.8586; Accuracy val: 0.8344
# Epoch 19; Accuracy train: 0.8592; Accuracy val: 0.8352
# Epoch 20; Accuracy train: 0.8599; Accuracy val: 0.8359
# Epoch 21; Accuracy train: 0.8610; Accuracy val: 0.8359
# Epoch 22; Accuracy train: 0.8624; Accuracy val: 0.8375
# Epoch 23; Accuracy train: 0.8629; Accuracy val: 0.8375
# Epoch 24; Accuracy train: 0.8638; Accuracy val: 0.8383
# Epoch 25; Accuracy train: 0.8641; Accuracy val: 0.8383
# Epoch 26; Accuracy train: 0.8644; Accuracy val: 0.8391
# Epoch 27; Accuracy train: 0.8645; Accuracy val: 0.8414
# Epoch 28; Accuracy train: 0.8646; Accuracy val: 0.8422
# Epoch 29; Accuracy train: 0.8646; Accuracy val: 0.8414
# Epoch 30; Accuracy train: 0.8651; Accuracy val: 0.8406
# Epoch 31; Accuracy train: 0.8651; Accuracy val: 0.8422
# Epoch 32; Accuracy train: 0.8654; Accuracy val: 0.8438
# Epoch 33; Accuracy train: 0.8659; Accuracy val: 0.8430
# Epoch 34; Accuracy train: 0.8660; Accuracy val: 0.8414
# Epoch 35; Accuracy train: 0.8660; Accuracy val: 0.8414
# Epoch 36; Accuracy train: 0.8661; Accuracy val: 0.8430
# Epoch 37; Accuracy train: 0.8662; Accuracy val: 0.8430
# Epoch 38; Accuracy train: 0.8665; Accuracy val: 0.8438
# Epoch 39; Accuracy train: 0.8666; Accuracy val: 0.8438
# Epoch 40; Accuracy train: 0.8671; Accuracy val: 0.8445
# Epoch 41; Accuracy train: 0.8669; Accuracy val: 0.8453
# Epoch 42; Accuracy train: 0.8671; Accuracy val: 0.8453
# Epoch 43; Accuracy train: 0.8675; Accuracy val: 0.8453
# Epoch 44; Accuracy train: 0.8676; Accuracy val: 0.8477
# Epoch 45; Accuracy train: 0.8680; Accuracy val: 0.8477
# Epoch 46; Accuracy train: 0.8688; Accuracy val: 0.8477
# Epoch 47; Accuracy train: 0.8691; Accuracy val: 0.8477
# Epoch 48; Accuracy train: 0.8692; Accuracy val: 0.8477
# Epoch 49; Accuracy train: 0.8692; Accuracy val: 0.8477
# Epoch 50; Accuracy train: 0.8698; Accuracy val: 0.8477
# Epoch 51; Accuracy train: 0.8696; Accuracy val: 0.8469
# Epoch 52; Accuracy train: 0.8699; Accuracy val: 0.8477
# Epoch 53; Accuracy train: 0.8700; Accuracy val: 0.8484
# Epoch 54; Accuracy train: 0.8701; Accuracy val: 0.8484
# Epoch 55; Accuracy train: 0.8701; Accuracy val: 0.8477
# Epoch 56; Accuracy train: 0.8706; Accuracy val: 0.8477
# Epoch 57; Accuracy train: 0.8714; Accuracy val: 0.8484
# Epoch 58; Accuracy train: 0.8715; Accuracy val: 0.8484
# Epoch 59; Accuracy train: 0.8714; Accuracy val: 0.8484
# Epoch 60; Accuracy train: 0.8714; Accuracy val: 0.8484
# Epoch 61; Accuracy train: 0.8716; Accuracy val: 0.8484
# Epoch 62; Accuracy train: 0.8718; Accuracy val: 0.8492
# Epoch 63; Accuracy train: 0.8721; Accuracy val: 0.8492
# Epoch 64; Accuracy train: 0.8724; Accuracy val: 0.8492
# Epoch 65; Accuracy train: 0.8725; Accuracy val: 0.8484
# Epoch 66; Accuracy train: 0.8722; Accuracy val: 0.8484
# Epoch 67; Accuracy train: 0.8725; Accuracy val: 0.8484
# Epoch 68; Accuracy train: 0.8726; Accuracy val: 0.8484
# Epoch 69; Accuracy train: 0.8729; Accuracy val: 0.8484
# Epoch 70; Accuracy train: 0.8729; Accuracy val: 0.8492
# Epoch 71; Accuracy train: 0.8730; Accuracy val: 0.8500
# Epoch 72; Accuracy train: 0.8732; Accuracy val: 0.8500
# Epoch 73; Accuracy train: 0.8735; Accuracy val: 0.8492
# Epoch 74; Accuracy train: 0.8739; Accuracy val: 0.8492
# Epoch 75; Accuracy train: 0.8741; Accuracy val: 0.8492
# Epoch 76; Accuracy train: 0.8742; Accuracy val: 0.8492
# Epoch 77; Accuracy train: 0.8739; Accuracy val: 0.8492
# Epoch 78; Accuracy train: 0.8738; Accuracy val: 0.8484
# Epoch 79; Accuracy train: 0.8739; Accuracy val: 0.8484
# Epoch 80; Accuracy train: 0.8739; Accuracy val: 0.8492
# Epoch 81; Accuracy train: 0.8738; Accuracy val: 0.8492
# Epoch 82; Accuracy train: 0.8740; Accuracy val: 0.8492
# Epoch 83; Accuracy train: 0.8744; Accuracy val: 0.8500
# Epoch 84; Accuracy train: 0.8746; Accuracy val: 0.8500
# Epoch 85; Accuracy train: 0.8748; Accuracy val: 0.8508
# Epoch 86; Accuracy train: 0.8749; Accuracy val: 0.8500
# Epoch 87; Accuracy train: 0.8750; Accuracy val: 0.8500
# Epoch 88; Accuracy train: 0.8748; Accuracy val: 0.8500
# Epoch 89; Accuracy train: 0.8750; Accuracy val: 0.8500
# Epoch 90; Accuracy train: 0.8749; Accuracy val: 0.8500
# Epoch 91; Accuracy train: 0.8748; Accuracy val: 0.8492
# Epoch 92; Accuracy train: 0.8749; Accuracy val: 0.8492
# Epoch 93; Accuracy train: 0.8750; Accuracy val: 0.8500
# Epoch 94; Accuracy train: 0.8750; Accuracy val: 0.8500
# Epoch 95; Accuracy train: 0.8750; Accuracy val: 0.8500
# Epoch 96; Accuracy train: 0.8751; Accuracy val: 0.8508
# Epoch 97; Accuracy train: 0.8751; Accuracy val: 0.8508
# Epoch 98; Accuracy train: 0.8754; Accuracy val: 0.8508
# Epoch 99; Accuracy train: 0.8756; Accuracy val: 0.8516

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

y_train = (y_train > 0).astype(int).ravel()
y_val = (y_val > 0).astype(int).ravel()

lr.fit(X_train, y_train)
train_out = lr.predict_proba(X_train)[:, 1]
val_out = lr.predict_proba(X_val)[:, 1]

auc_train = average_precision_score(y_train, train_out)
auc_val = average_precision_score(y_val, val_out)

print(f'Accuracy train: {auc_train:.4f}; Accuracy val: {auc_val:.4f}')
# Out:
# Accuracy train: 0.9022; Accuracy val: 0.8713
